# %%
import numpy as np
import pandas as pd
from ggplot import *
# %matplotlib inline

# %%
data = pd.DataFrame(np.random.rand(200, 3), columns=['x', 'y', 'z'])
p = ggplot(aes(x='x', y='y'), data)
p
# Out:
# <ggplot: (-9223363264764929532)>

# %%
p + geom_point()
# Out:
# <ggplot: (8772090603058)>

# %%
p + geom_point() + geom_line()
# Out:
# <ggplot: (8772089419475)>

# %%
p + geom_point() + geom_line() + stat_smooth(color='blue')
# Out:
# <ggplot: (-9223363264765376168)>

# %%
p + geom_line() + geom_now_its_art()
# Out:
# Put a bird on it!
# <ggplot: (-9223363264765313094)>
